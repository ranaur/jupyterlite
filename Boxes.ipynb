# %%
import sys
sys.path.append('/drive/boxes') # uncomments and adjust if your Boxes.py copy in not in the Python path
sys.path.append('/drive/boxes/boxes') # uncomments and adjust if your Boxes.py copy in not in the Python path

# %%
import piplite
await piplite.install(["affine>=2.0", "markdown", "numpy", "PyYAML", "qrcode>=7.3.1", "rectpack", "setuptools", "shapely>=1.8.2", "sphinx", "svgpathtools", "typing_extensions>=4.5.0"])

# %%
from boxes import *

# %%
print(boxes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(boxes)
#
# NameError: name 'boxes' is not defined

# %% [raw]
# print(boxes.__dict__)
